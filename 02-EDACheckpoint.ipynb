# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# Team list and credits:
# - Muska Mesdaq: Background research, Writing - original draft, Writing - review & editing, Data Overview, Data Wrangling
# - Shourya Kulkarni: Analysis, Data Overview, Ethics, Writing - review & editing, Writing - original draft
# - Jasmine Le: Software, Data Wrangling,  Analysis, Background research, Visualization, Investigation, Writing - original draft, Writing - review & editing
# - Pauline Shah: Data Overview, Analysis, Writing - review & editing, Writing - original draft

# %% [markdown]
# # Research Question

# %% [markdown]
# What product attributes, such as material, color, category, origin, gender-target (gender product is marketed to), and popularity (measured by difference from mean number of ratings for garment type) most influence pricing in U.S. dollars of athleticwear in the U.S.?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The prevalence of athletic wear, whether worn for leisure or actual activity, has been on the rise.  In fact, the athletic wear market now represents a substantial and rapidly growing segment of the global apparel industry, with the North American market alone valued at over 26 billion dollars in 2024, and a projected value of 677.26 billion dollars by 2030.  Among other things, this rapid growth can be attributed to a culture that is increasingly health-conscious, and the not-unrelated merging of fashion and functionality, dubbed "athlesiure". As casually-worn athletic wear becomes increasingly mainstream, however, there is the question of cost - specifically, what factors make it cost what is does?
#
#
# Now, the question of what drives apparel pricing has been examined before.  Multiple countries have used the hedonic model to calculate the Consumer Price Index, used to track inflation, for apparel in their countries. The hedonic model uses regression to "estimate a value for each characteristic of the item", which then all sum to the total price of the item. <a name="https://www.bls.gov/cpi/quality-adjustment/questions-and-answers.htm"></a>[<sup>1</sup>](#https://www.bls.gov/cpi/quality-adjustment/questions-and-answers.htm) The use of this technique allows researchers to make adjustments to account for seasonal changes and evolving product characteristics, essentially isolating the contribution of individual attributes to overall product pricing.
#
#
# One factor, material composition, represents one of the most fundamental drivers of garment pricing, with significant research demonstrating its importance. In the active wear market, synthetic materials were very popular, supported by widespread use of polyester, which has moisture-wicking properties and is durable, important qualities for active wear to have.<a name="https://www.marketresearchfuture.com/reports/sportswear-fabric-market-37412"></a>[<sup>2</sup>](#https://www.marketresearchfuture.com/reports/sportswear-fabric-market-37412)However, consumer preferences are evolving with the times, and natural materials like organic cotton and bamboo blends are becoming more popular as eco-friendly and sustainable products, since sustainability has become a more mainstream concern.  The price consumers are willing to pay for sustainable materials has been documented before. Research on outdoor apparel using hedonic pricing models found that material type had a statistically significant impact on item price, with different materials like cotton, polyester, wool, and nylon valued at different price points based on their breathability, durability, and environmental impact.<a name="https://www.researchgate.net/publication/332530663_The_Outdoor_Apparel_IndustryMeasuring_the_Premium_for_Sustainability_with_a_Hedonic_Pricing_Model"></a>[<sup>3</sup>](#https://www.researchgate.net/publication/332530663_The_Outdoor_Apparel_IndustryMeasuring_the_Premium_for_Sustainability_with_a_Hedonic_Pricing_Model) Not to mention, raw material price fluctuations also significantly impact manufacturing costs for brands, with materials such as organic cotton subject to changes in supply and demand as well as energy and transportation costs. This cost pressure directly influences retail pricing strategies, as manufacturers must balance quality expectations with competitive pricing.
#
# Another important consideration for pricing that transcends the realm of clothing is the "Pink Tax", or gender based pricing.  This is a recorded phenomenon, even reported on by the U.S. Congress's Joint Economic Committee, which notes that "... the frequency with which female consumers find themselves paying higher prices for gender-specific goods and services effectively becomes a tax on being a woman".<a name="https://www.jec.senate.gov/public/_cache/files/8a42df04-8b6d-4949-b20b-6f40a326db9e/the-pink-tax---how-gender-based-pricing-hurts-women-s-buying-power.pdf"></a>[<sup>4</sup>](#https://www.jec.senate.gov/public/_cache/files/8a42df04-8b6d-4949-b20b-6f40a326db9e/the-pink-tax---how-gender-based-pricing-hurts-women-s-buying-power.pdf) Gender-targeted marketing and its relationship to pricing represents one of the most controversial aspects of apparel pricing research, with another 2015 study by the New York City Department of Consumer Affairs finding that women's clothing was 8% more expensive than men's clothing on average.<a name="https://www.nyc.gov/assets/dca/downloads/pdf/partners/Study-of-Gender-Pricing-in-NYC.pdf"></a>[<sup>5</sup>](#https://www.nyc.gov/assets/dca/downloads/pdf/partners/Study-of-Gender-Pricing-in-NYC.pdf) Not only that, but women's clothing imports face higher average tariff rates than men's clothing, with women's clothing at 15.1% compared to 11.9% for men.<a name="http://bush.tamu.edu/wp-content/uploads/2020/07/V6-3-Tariff-Discrimination-Takeaway.pdf"></a>[<sup>6</sup>](#http://bush.tamu.edu/wp-content/uploads/2020/07/V6-3-Tariff-Discrimination-Takeaway.pdf) However, other research challenges the notion of gender-based pricing. Studies like these find that most comparable products differed in their ingredient compositions, suggesting that price differences may reflect genuine product differentiation rather than discriminatory pricing. <a name="https://pubsonline.informs.org/doi/pdf/10.1287/mksc.2023.1452"></a>[<sup>7</sup>](#https://pubsonline.informs.org/doi/pdf/10.1287/mksc.2023.1452) The debate centers on distinguishing between legitimate reasons in pricing difference and discriminatory practices, something we wish to also explore on a smaller level, in our analysis of what determines the cost of athletic wear.
#
#
# Country of origin (COO) represents another well-established driver of consumer perceptions and pricing in apparel markets. The COO effect describes how consumers' attitudes, perceptions, and purchasing decisions are influenced by products' country of origin labeling, which may refer to where a brand is based, where products are designed, or where they are manufactured.  Research has empirically demonstrated that the COO effect has significant price-related consequences, with brands possessing favorable COO associations able to charge price premiums over and above those attributed to observable product differentiation <a name="https://link.springer.com/article/10.1007/s11747-012-0318-1"></a>[<sup>8</sup>](#https://link.springer.com/article/10.1007/s11747-012-0318-1). The strength of COO effects varies considerably by product category and consumer characteristics. In apparel specifically, research examining clothing from multiple countries found that COO was related to assessment of product quality, but when evaluating purchase likelihood, COO seemed not to be as important, suggesting a more complex situation.<a name="https://www.researchgate.net/publication/318283638_The_Country-of-Origin_Construct_and_Its_Effect_on_Consumer_Behavior_A_Review_of_Selected_Literature_and_Proposed_Future_Research_Directions"></a>[<sup>9</sup>](#https://www.researchgate.net/publication/318283638_The_Country-of-Origin_Construct_and_Its_Effect_on_Consumer_Behavior_A_Review_of_Selected_Literature_and_Proposed_Future_Research_Directions)
#
# The influence of popularity metrics on pricing is a newer area of research enabled by e-commerce platforms, which we choose to measure in the form of customer reviews and ratings in the absence of actual total purchasing data. Consumer surveys consistently shows that ratings and reviews are considered very important, with up to 98% of shoppers saying reviews are an "essential resource when making purchase decisions".<a name="https://www.powerreviews.com/power-of-reviews-2023/"></a>[<sup>10</sup>](#https://www.powerreviews.com/power-of-reviews-2023/) Research also demonstrates that products with five reviews have 270% greater purchase likelihood than products with no reviews, but these benefits diminish rapidly after the first five reviews, according to Northwestern.<a name="https://spiegel.medill.northwestern.edu/how-online-reviews-influence-sales/"></a>[<sup>11</sup>](#https://spiegel.medill.northwestern.edu/how-online-reviews-influence-sales/) Conjoint analysis research also indicates that "consumers considered star rating, number of reviews, online shopping platform, and premium reviews to be more important than price when making an online shopping decision". <a name="https://www.nature.com/articles/s41599-023-02277-7"></a>[<sup>12</sup>](#https://www.nature.com/articles/s41599-023-02277-7) However, there are many factors that differentiate from study to study, and so we would like to uncover ourselves how perceived popularity influence product pricing in the realm of active wear.
#
#
# While individual attributes influencing apparel pricing have been studied on their own, comprehensive research examining the effects of material, color, category, origin, gender-targeting, and popularity metrics specifically within the athleticwear segment is still limited. As such, we plan to employ a comprehensive dataset of U.S. athleticwear products to try to quantify the relative importance of these diverse attributes in determining price, and hopefully providing insight into the factors that decide how much a product costs.
#
# Athleticwear has become one of the biggest parts of the fashion industry, especially with the rise of fitness culture and athleisure clothing. Big brands like Adidas have built their image around performance and lifestyle wear, selling products that mix comfort, function, and style. Research on fashion pricing has shown that things like brand reputation, material quality, and product design have a big impact on how much items cost online. One study found that brands with stronger reputations tend to keep higher prices and are less likely to discount their items. [Source](https://www.jstage.jst.go.jp/article/isase/ISASE2019/0/ISASE2019_1_8/_article?utm_source)
#
# Another study on denim clothing showed that items made from unique or mixed materials often had higher prices because people see them as higher quality. [Source](https://www.mdpi.com/2673-7248/3/1/2?utm_source)
#
# For Adidas specifically, there’s been some research on its marketing and pricing strategies, but not much on what exact product attributes drive those prices. One paper mentioned that Adidas focuses heavily on innovation and sustainability while still trying to improve how it prices and markets its products. [Source](https://www.ewadirect.com/proceedings/aemps/article/view/3640?utm_source)
#
# Another study found that brand image, product quality, and marketing are major factors influencing how customers view Adidas and what they’re willing to pay. [Source](https://bsq.cultechpub.com/index.php/bsq/article/view/2?utm_source)
#
# Even though these studies show that branding and quality matter, they don’t really dig into which features like material, color, or product category make certain Adidas items cost more than others. Our project aims to explore that gap by analyzing online pricing data for Adidas products in the U.S. to see which product details have the biggest impact on price.
#
# Sources:
#
#
# 1. <a name="https://www.bls.gov/cpi/quality-adjustment/questions-and-answers.htm"></a> [^](#https://www.bls.gov/cpi/quality-adjustment/questions-and-answers.htm) Consumer Price Index *U.S. BUREAU OF LABOR STATISTICS* https://www.bls.gov/cpi/quality-adjustment/questions-and-answers.htm
#
# 2.  <a name="https://www.marketresearchfuture.com/reports/sportswear-fabric-market-37412"></a> [^](#https://www.marketresearchfuture.com/reports/sportswear-fabric-market-37412) Sportswear Fabric Market *Market Research Future* https://www.marketresearchfuture.com/reports/sportswear-fabric-market-37412
#
# 3.   <a name="https://www.researchgate.net/publication/332530663_The_Outdoor_Apparel_IndustryMeasuring_the_Premium_for_Sustainability_with_a_Hedonic_Pricing_Model"></a> [^](#https://www.researchgate.net/publication/332530663_The_Outdoor_Apparel_IndustryMeasuring_the_Premium_for_Sustainability_with_a_Hedonic_Pricing_Model) Lindahl, E. (Janurary 2018) The Outdoor Apparel Industry:Measuring the Premium for Sustainability with a Hedonic Pricing Model *Scripps College* https://www.researchgate.net/publication/332530663_The_Outdoor_Apparel_IndustryMeasuring_the_Premium_for_Sustainability_with_a_Hedonic_Pricing_Model
#
# 4. <a name="https://www.jec.senate.gov/public/_cache/files/8a42df04-8b6d-4949-b20b-6f40a326db9e/the-pink-tax---how-gender-based-pricing-hurts-women-s-buying-power.pdf"></a> [^](#https://www.jec.senate.gov/public/_cache/files/8a42df04-8b6d-4949-b20b-6f40a326db9e/the-pink-tax---how-gender-based-pricing-hurts-women-s-buying-power.pdf) (December 2016) The Pink Tax
# How Gender-Based Pricing Hurts Women’s Buying Power *United States Congress Joint Economic Committee* https://www.jec.senate.gov/public/_cache/files/8a42df04-8b6d-4949-b20b-6f40a326db9e/the-pink-tax---how-gender-based-pricing-hurts-women-s-buying-power.pdf
#
# 5. <a name="https://www.nyc.gov/assets/dca/downloads/pdf/partners/Study-of-Gender-Pricing-in-NYC.pdf"></a> [^](#https://www.nyc.gov/assets/dca/downloads/pdf/partners/Study-of-Gender-Pricing-in-NYC.pdf) Bessendorf, A. (December 2015) From Cradle to Cane: The Cost of Being a Female Consumer - A Study of Gender Pricing in New York City *New York City Department of Consumer Affairs* https://www.nyc.gov/assets/dca/downloads/pdf/partners/Study-of-Gender-Pricing-in-NYC.pdf
#
# 6. <a name="http://bush.tamu.edu/wp-content/uploads/2020/07/V6-3-Tariff-Discrimination-Takeaway.pdf"></a> [^](#http://bush.tamu.edu/wp-content/uploads/2020/07/V6-3-Tariff-Discrimination-Takeaway.pdf) Taylor, L., Dar, J. (2015) Fairer Trade Removing Gender Bias in US Import Taxes *Mosbacher Institute for Trade, Economics, & Public Policy* http://bush.tamu.edu/wp-content/uploads/2020/07/V6-3-Tariff-Discrimination-Takeaway.pdf
#
# 7. <a name="https://pubsonline.informs.org/doi/pdf/10.1287/mksc.2023.1452"></a> [^](#https://pubsonline.informs.org/doi/pdf/10.1287/mksc.2023.1452)  Moshary, S., Tuchman, A., Vajravelu, N. (2023) Gender-Based Pricing in Consumer Packaged Goods: A Pink Tax?. *Marketing Science* https://pubsonline.informs.org/doi/pdf/10.1287/mksc.2023.1452
#
# 8.  <a name="https://link.springer.com/article/10.1007/s11747-012-0318-1"></a> [^](#https://link.springer.com/article/10.1007/s11747-012-0318-1) Florian M., Diamantopoulos A. (19 October 2012) Activation of country stereotypes: automaticity, consonance, and impact *Journal of the Academy of Marketing Science* https://link.springer.com/article/10.1007/s11747-012-0318-1
#
# 9. <a name="https://www.researchgate.net/publication/318283638_The_Country-of-Origin_Construct_and_Its_Effect_on_Consumer_Behavior_A_Review_of_Selected_Literature_and_Proposed_Future_Research_Directions"></a> [^](#https://www.researchgate.net/publication/318283638_The_Country-of-Origin_Construct_and_Its_Effect_on_Consumer_Behavior_A_Review_of_Selected_Literature_and_Proposed_Future_Research_Directions) Boutin Jr, P. (2011) The Country-of-Origin Construct and Its Effect on Consumer Behavior: A Review of Selected Literature and Proposed Future Research Directions.  https://www.researchgate.net/publication/318283638_The_Country-of-Origin_Construct_and_Its_Effect_on_Consumer_Behavior_A_Review_of_Selected_Literature_and_Proposed_Future_Research_Directions
#
# 10. <a name="https://www.powerreviews.com/power-of-reviews-2023/"></a> [^](#https://www.powerreviews.com/power-of-reviews-2023/) The Ever-Growing Power of Reviews (2023 Edition) *Power Reviews* https://www.powerreviews.com/power-of-reviews-2023/
#
# 11. <a name="https://spiegel.medill.northwestern.edu/how-online-reviews-influence-sales/"></a> [^](#https://spiegel.medill.northwestern.edu/how-online-reviews-influence-sales/) How Online Reviews Influence Sales *Northwestern University Medill Spiegel Research Center* https://spiegel.medill.northwestern.edu/how-online-reviews-influence-sales/
#
# 12. <a name="https://www.nature.com/articles/s41599-023-02277-7"></a> [^](#https://www.nature.com/articles/s41599-023-02277-7) Sung, E., Chung, W.Y. & Lee, D. (01 November 2023) Factors that affect consumer trust in product quality: a focus on online reviews and shopping platforms. *Humanit Soc Sci Commun 10, 766*  https://doi.org/10.1057/s41599-023-02277-7

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that origin and material are the product attributes that will most influence the pricing of athleticwear.
#
# This is due to the nature of the clothing industry, which heavily relies on outsourcing work to foreign countries to reduce cost of production for goods, and a common occurance in many industries due to globalization, and comes down to companies being able to create their products with lower expenses elsewhere.
#
# We also believe material is a product attribute that will most influence pricing of athleticwear, as the actual cost of the material that is used to make the product is a logical factor in it's pricing, as not all materials are created equal.  For instance, materials like polyester cost less than something like merino wool, as polyester is a synthetic material derived from plastic and is easy and inexpensive to make, while merino wool is a natural material that is cost and labor intensive to create - meaning that the same item made of polyester versus merino wool would have drastically different costs to produce.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# ### Dataset #1
# - **Dataset Name**: Data on Adidas products available for purchase in the United States
# - **Link**: https://www.kaggle.com/datasets/thedevastator/adidas-fashion-retail-products-dataset-9300-prod
# - **Number of observations**: ~9,300
# - **Number of variables**: 12
# - **Description of the variables most relevant to this project**
# - `product_name`: The name of the item, which often includes indicators of category and style.
# - `category`: The product type (e.g., shoes, shirts, pants), used to analyze category-level pricing trends.
# - `color`: The color of the product, included to test whether color influences pricing.
# - `gender`: The gender the product is marketed to (Men, Women, Unisex), relevant for exploring possible gender-based pricing differences.
# - `price`: The listed retail price of the item — our dependent variable of interest.
# - `average_rating`: The average customer rating, representing consumer perception of product quality.
# - `reviews_count`: The total number of customer reviews, used as a proxy for popularity or demand.
# - `description`: A short text summary of the product, which may contain information on material, features, or use case.
# - `product_link` and `image_link`: Contain URLs for product pages and images; not used in modeling but useful for reference.
# - **Descriptions of any shortcomings**:
#     - Missing material composition (e.g., cotton vs. polyester blend)
#     - Missing production cost and sales frequency, likely proprietary
#     - Imbalanced representation — heavily skewed toward Adidas products
#     - Some missing values for `average_rating` and `reviews_count`
#     - Text-based variables (`description`) require parsing to extract structured information
#
# Despite these limitations, this dataset provides a strong foundation for exploring pricing patterns, consumer ratings, and category-based trends in the athletic wear market.
#
# ### Dataset #2
# - **Dataset Name**: Adidas vs. Nike
# - **Link**: [Kaggle Dataset](https://www.kaggle.com/datasets/kaushiksuresh147/adidas-vs-nike)
# - **Number of observations**: 3,268
# - **Number of variables**: 10
# - **Description of the variables most relevant to this project**:
#   - Listing Price and Sale Price (in U.S. cents) allow analysis of original pricing vs. markdowns. Example: 14,999 cents = $149.99.
#   - Discount (whole number) indicates reduction from Listing Price.
#   - Ratings (1-5) capture customer satisfaction, with 5 = highly satisfied.
#   - Reviews show the number of customer reviews.
#   - Brand, Product Name, Product ID, Description, and Last Visited (timestamp) provide product and engagement context.
# - **Descriptions of any shortcomings**: may have missing values, limited coverage of attributes.
#
# This dataset includes several key metrics describing both Adidas and Nike products. Listing Price and Sale Price are recorded in U.S. cents, enabling analysis of price reductions. Discount shows how much the Sale Price is reduced. Ratings and Reviews provide customer engagement insights. Brand, Product Name, Product ID, Description, and Last Visited provide additional context.
#
# This dataset may contain several sources of bias. Data comes mainly from online shoppers, excluding in-store customers, introducing self-selection bias. Online shoppers may differ in purchasing habits and characteristics. Because the research focuses solely on Adidas, Nike entries will be removed during preprocessing. Therefore, analysis results cannot be generalized to the broader athleticwear industry; insights will only apply to Adidas products in an online shopping context.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://docs.google.com/spreadsheets/d/1uY8CXk0YVhfRWrc33uB-EuVNiGr6Yfk_onANakfmtiM/export?format=csv', 'filename':'Adidas.csv'},
    { 'url': 'https://docs.google.com/spreadsheets/d/1trv0qgSw309WBvxbX98bGXyBnq3v2KfbxYs_kt8-4Fw/export?format=csv', 'filename':'Adidas_vs_Nike.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress:   0%|                          | 0/2 [00:00<?, ?it/s]
# Downloading Adidas.csv: 0.00B [00:00, ?B/s]
# Overall Download Progress:  50%|█████████         | 1/2 [00:00<00:00,  1.28it/s]
# Successfully downloaded: Adidas.csv
# Downloading Adidas_vs_Nike.csv: 0.00B [00:00, ?B/s]
# Overall Download Progress: 100%|██████████████████| 2/2 [00:01<00:00,  1.13it/s]
# Successfully downloaded: Adidas_vs_Nike.csv

# %% [markdown]
# ### Dataset #1 : Adidas U.S. Athleticwear Dataset
#
# ### Key Variables and Metrics
# - **Product Name / Brand**: Identifies the item and confirms it belongs to Adidas.
# - **Garment Subtype**: Describes the product type (e.g., *T-shirt*, *Shorts*, *Leggings*, *Jacket*). Useful for comparing price differences between categories.
# - **Material Composition**: Describes the fabric makeup (e.g., *60% cotton, 40% polyester*). Synthetic materials like polyester are durable and cheaper, while natural fibers like organic cotton can increase price due to sustainability value.
# - **Color**: The primary color of the garment (categorical). Limited-edition colors or trendy shades may be priced higher.
# - **Gender**: The target audience—*Men*, *Women*, or *Unisex*. Allows testing for gender-based pricing (“Pink Tax”).
# - **Country of Production**: Where the item was manufactured (e.g., *Vietnam, China, Indonesia*). May affect cost because of labor and production expenses.
# - **Customer Rating**: Average rating (1–5 stars) reflecting consumer satisfaction. A higher rating may suggest higher perceived value or quality.
# - **Number of Reviews**: Total customer reviews, a proxy for product popularity or sales volume.
# - **Sale Price (USD)**: The main outcome variable, representing listed retail price in U.S. dollars.
#
# ### Potential Data Concerns and Biases
# - **Online Marketplace Bias**: The dataset is sourced from online listings, which may not represent in-store pricing or promotional discounts.
# - **Self-Selection Bias**: Popular products with more reviews are overrepresented, while new or niche products might lack visibility.
# - **Missing or Inconsistent Entries**: Some records may have missing *country*, *rating*, or *review count* fields, especially for newly listed products.
# - **Duplicate Products**: Variants of the same item (e.g., same shirt in multiple colors) may appear multiple times and need consolidation.
# - **Temporal Variation**: Prices may change over time due to promotions, seasonal trends, or clearance sales.
#
# 2. Use the cell below to:
#     1. Load the dataset.
#     2. Make the dataset tidy or demonstrate that it was already tidy.
#     3. Demonstrate the size of the dataset.
#     4. Find out how much data is missing, where it's missing, and if it's missing at random or shows systematic patterns.
#     5. Find and flag any outliers or suspicious entries.
#     6. Clean the data or demonstrate that it was already clean. You may choose how to deal with missingness (`dropna` or `fillna`, with `how='any'` or `how='all'`), and you should justify your choice.
#     7. You will load raw data from `data/00-raw/`, optionally write intermediate stages to `data/01-interim/`, and write the final fully wrangled version of your data to `data/02-processed/`.
#
# 3. Optionally, you can also show some summary statistics for variables that you think are important to the project.
# 4. Feel free to add more cells here if that's helpful for you.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# Load data
df = pd.read_csv("data/00-raw/Adidas.csv")

# Show basic info
print('Shape:', df.shape)
display(df.head())

# Missingness check
print('\nMissing values:\n', df.isnull().sum())

sns.heatmap(df.isnull(), cbar=False)
plt.title('Missing Data Heatmap')
plt.show()

# Detect outliers in price
sns.boxplot(x=df['selling_price'])
plt.title('Price Distribution and Outliers')
plt.show()


#Cleaning data:

##duplicates dropped
df = df.drop_duplicates()

##Missing values dropped
df = df.dropna(subset=['original_price'])

##Making original price usable for analysis by removing "$" 
df["original_price"] = df["original_price"].str.split("$").str[1].astype(float) 

# Missingness check -- all missing values are gone
print('\nMissing values:\n', df.isnull().sum())

#categorizing as gender products
def gender(text):
    men_pattern = r"\b" + re.escape("men") + r"\b"
    women_pattern = r"\b" + re.escape("women") + r"\b"
    if re.search(men_pattern, text):
        return "Men's product"
    if re.search(women_pattern, text):
        return "Women's product"
    else:
        return "Unisex product"
        
df["gender"] = df["breadcrumbs"].str.lower().transform(gender)

##adding name to description for consistency across data
df["description"] = df["name"] + ": " + df["description"]

#categorizing as type of products
def product_type(text):
    shoes = r"\b" + re.escape("shoes") + r"\b"
    clothing = r"\b" + re.escape("clothing") + r"\b"
    accessories = r"\b" + re.escape("accessories") + r"\b"
    if re.search(shoes, text):
        return "footwear"
    if re.search(clothing, text):
        return "clothing"
    if re.search(accessories, text):
        return "accessories"
    else:
        return "other"
        
df["product_type"] = df["breadcrumbs"].str.lower().transform(product_type)

#defining popularity in terms of review counts 
def popularity(numerical_input):
    if numerical_input <= 50:
        return "low popularity"
    if (numerical_input > 50) & (numerical_input <= 100):
        return "medium popularity"
    if (numerical_input > 100) & (numerical_input <= 150):
        return "high popularity"
    if numerical_input > 150:
        return "very high popularity"
df["popularity"] = df["reviews_count"].transform(popularity)

# Save cleaned version
df.to_csv('data/02-processed/Adidas_cleaned.csv')

# Detect outliers in listing price
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['original_price'])
plt.title('Listing Price Distribution and Outliers')
plt.show()

# Detect outliers in sales price
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['selling_price'])
plt.title('Sales Price Distribution and Outliers')
plt.show()

# looking at distribution in Listing price 
plt.figure(figsize=(20, 10))
sns.histplot(data=df, x='original_price', bins =30)
plt.title('Listing Price Distribution')
plt.show()

# looking at distribution in sales price 
plt.figure(figsize=(20, 10))
sns.histplot(data=df, x='selling_price', bins =30)
plt.title('Sale Price Distribution')
plt.show()


# Looking at differences in listing price based on target gender
plt.figure(figsize=(10, 6))
sns.boxplot(data = df , x='original_price' , hue ="gender" )
plt.title('Listing Price Distribution by Gender Target')
plt.show()

# Looking at differences in sales price based on target gender
plt.figure(figsize=(10, 6))
sns.boxplot(data = df , x='selling_price' , hue ="gender" )
plt.title('Sale Price Distribution by Gender Target')
plt.show()

# looking at differences in listing price based on target gender and product type 
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='product_type', y='original_price', hue='gender')
plt.title('Mean Listing Price by Product Type and Gender')
plt.show()

# looking at differences in sale price based on target gender and product type 
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='product_type', y='selling_price', hue='gender')
plt.title('Mean Sale Price by Product Type and Gender')
plt.show()

# looking at correlation in listing price based on review count and product type 
sns.scatterplot(data=df, x='original_price', y='reviews_count')
plt.title('Rating vs Listing Price Correlation')
plt.show()

# looking at correlation in sales price based on review count and product type 
sns.scatterplot(data=df, x='selling_price', y='reviews_count')
plt.title('Rating vs Sale Price Correlation')
plt.show()

# looking at distribution in listing price by popularity (based on review counts)
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x='original_price', hue='popularity')
plt.title('Listing Price Distribution by Popularity (based on review counts)')
plt.show()

# looking at distribution in sale price by popularity (based on review counts)
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x='selling_price', hue='popularity')
plt.title('Sale Price Distribution by Popularity (based on review counts)')
plt.show()



#summary statistics and information about the dataframe
df.info()

df.describe()
# Out:
# Shape: (845, 21)
#    index                                                url  \
# 0      0  https://www.adidas.com/us/beach-shorts/FJ5089....
# 1      1  https://www.adidas.com/us/five-ten-kestrel-lac...
# 2      2  https://www.adidas.com/us/mexico-away-jersey/G...
# 3      3  https://www.adidas.com/us/five-ten-hiangle-pro...
# 4      4  https://www.adidas.com/us/mesh-broken-stripe-p...
#
#                                               name     sku  selling_price  \
# 0                                     Beach Shorts  FJ5089             40
# 1        Five Ten Kestrel Lace Mountain Bike Shoes  BC0770            150
# 2                               Mexico Away Jersey  GC7946             70
# 3  Five Ten Hiangle Pro Competition Climbing Shoes  FV4744            160
# 4                    Mesh Broken-Stripe Polo Shirt  GM0239             65
#
#   original_price currency availability  color  category  ...  \
# 0            NaN      USD      InStock  Black  Clothing  ...
# 1            NaN      USD      InStock   Grey     Shoes  ...
# 2            NaN      USD      InStock  White  Clothing  ...
# 3            NaN      USD      InStock  Black     Shoes  ...
# 4            NaN      USD      InStock   Blue  Clothing  ...
#
#            source_website     breadcrumbs  \
# 0  https://www.adidas.com  Women/Clothing
# 1  https://www.adidas.com     Women/Shoes
# 2  https://www.adidas.com   Kids/Clothing
# 3  https://www.adidas.com  Five Ten/Shoes
# 4  https://www.adidas.com    Men/Clothing
#
#                                          description   brand  \
# 0  Splashing in the surf. Making memories with yo...  adidas
# 1  Lace up and get after it. The Five Ten Kestrel...  adidas
# 2  Clean and crisp, this adidas Mexico Away Jerse...  adidas
# 3  The Hiangle Pro takes on the classic shape of ...  adidas
# 4  Step up to the tee relaxed. This adidas golf p...  adidas
#
#                                               images country language  \
# 0  https://assets.adidas.com/images/w_600,f_auto,...     USA       en
# 1  https://assets.adidas.com/images/w_600,f_auto,...     USA       en
# 2  https://assets.adidas.com/images/w_600,f_auto,...     USA       en
# 3  https://assets.adidas.com/images/w_600,f_auto,...     USA       en
# 4  https://assets.adidas.com/images/w_600,f_auto,...     USA       en
#
#   average_rating  reviews_count  crawled_at
# 0            4.5             35     50:17.3
# 1            4.8              4     50:17.4
# 2            4.9             42     50:17.5
# 3            3.7              7     50:17.6
# 4            4.7             11     50:17.7
#
# [5 rows x 21 columns]
# Missing values:
#  index              0
# url                0
# name               0
# sku                0
# selling_price      0
# original_price    16
# currency           0
# availability       0
# color              0
# category           0
# source             0
# source_website     0
# breadcrumbs        0
# description        0
# brand              0
# images             0
# country            0
# language           0
# average_rating     0
# reviews_count      0
# crawled_at         0
# dtype: int64
# Missing values:
#  index             0
# url               0
# name              0
# sku               0
# selling_price     0
# original_price    0
# currency          0
# availability      0
# color             0
# category          0
# source            0
# source_website    0
# breadcrumbs       0
# description       0
# brand             0
# images            0
# country           0
# language          0
# average_rating    0
# reviews_count     0
# crawled_at        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 829 entries, 15 to 844
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           829 non-null    int64
#  1   url             829 non-null    object
#  2   name            829 non-null    object
#  3   sku             829 non-null    object
#  4   selling_price   829 non-null    int64
#  5   original_price  829 non-null    float64
#  6   currency        829 non-null    object
#  7   availability    829 non-null    object
#  8   color           829 non-null    object
#  9   category        829 non-null    object
#  10  source          829 non-null    object
#  11  source_website  829 non-null    object
#  12  breadcrumbs     829 non-null    object
#  13  description     829 non-null    object
#  14  brand           829 non-null    object
#  15  images          829 non-null    object
#  16  country         829 non-null    object
#  17  language        829 non-null    object
#  18  average_rating  829 non-null    float64
#  19  reviews_count   829 non-null    int64
#  20  crawled_at      829 non-null    object
#  21  gender          829 non-null    object
#  22  product_type    829 non-null    object
#  23  popularity      829 non-null    object
# dtypes: float64(2), int64(3), object(19)
# memory usage: 161.9+ KB
#             index  selling_price  original_price  average_rating  \
# count  829.000000     829.000000      829.000000      829.000000
# mean   429.997587      52.911942       69.008444        4.608323
# std    239.460157      31.151542       40.490127        0.292690
# min     15.000000       9.000000       14.000000        1.000000
# 25%    223.000000      28.000000       35.000000        4.500000
# 50%    430.000000      48.000000       65.000000        4.700000
# 75%    637.000000      68.000000       90.000000        4.800000
# max    844.000000     240.000000      300.000000        5.000000
#
#        reviews_count
# count     829.000000
# mean      433.943305
# std      1239.690004
# min         1.000000
# 25%        20.000000
# 50%        72.000000
# 75%       319.000000
# max     11750.000000

# %% [markdown]
# ## Dataset #2: Adidas vs. Nike
#
# This dataset includes several key metrics that describe both Adidas and Nike products. The Listing Price and the Sale Price are recorded in U.S. cents, which allows us to analyze the original pricing and the markdowns of the products.For example, a product listed as 14,999 U.S.cents would cost 149.99 U.S. dollars, and a product sold for 7,499 U.S. cents would be 74.99 U.S. dollars. The Discount metric is expressed as a whole number, and shows how much the Sale Price is reduced in comparison to the Listing Price. The dataset also captures customer engagement metrics through Ratings (from a scale of 1-5) where 1 indicates dissatisfaction with the product and 5 indicates high satisfaction, and Reviews, which records the number of reviews a particular product has received. Some additional features in the dataset include the Brand of the listed product (whether it is Nike or Adidas), the Name of the specific product, its Product ID which consists of a combination of numbers and letters, a brief Description of the product (in a text summary format), and Last Visited (a timestamp of the most recent customer interaction with the product). These listed metrics provide insight for certain characteristics within a product and the customer interests associated with them.
#
# The dataset may contain several sources of bias and limitations, despite the number of metrics it has. Because the data is taken mainly from online shoppers, it reflects the individuals who use e-commerce platforms and online shops/websites to purchase these products, and excludes consumers who shop in-person at physical retail stores. This introduces self-selection bias, since online shoppers may have different purchasing habits and characteristics, such as possibly  being more technologically comfortable, in comparison to in-store shoppers. The data from the dataset is also restricted to Nike and Adidas, and since our research only focuses on Adidas, the entries of the Nike data will be removed during the preprocessing. Due to the research’s sole focus on Adidas, the results of our analysis cannot be generalized for the broader athleticwear industry. Any insights received from our analysis will be for Adidas products within the online shopping context.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# Load data
df_2 = pd.read_csv("data/00-raw/Adidas_vs_Nike.csv")

# Show basic info
print('Shape:', df_2.shape)
display(df_2.head())

# Missingness check
print('\nMissing values:\n', df_2.isnull().sum())

sns.heatmap(df_2.isnull(), cbar=False)
plt.title('Missing Data Heatmap')
plt.show()

# Cleaning
df_2 = df_2.loc[df_2["Brand"] != "Nike"] ##removing nike products from data
df_2 = df_2.drop_duplicates() #dropping duplicates, if any 
df_2 = df_2.dropna(subset=['Description'])  ##dropping 3 with missing descriptions 
df_2["Sale Price"] = df_2["Sale Price"]/100 ##converting price from pennies to dollar ammount
df_2["Listing Price"] = df_2["Listing Price"]/100 ##converting price from pennies to dollar ammount

# Missingness check -- no more missing values
print('\nMissing values:\n', df_2.isnull().sum())


#categorizing as gender products
def gender(text):
    men_pattern = r"\b" + re.escape("men's") + r"\b"
    women_pattern = r"\b" + re.escape("women's") + r"\b"
    if re.search(men_pattern, text):
        return "Men's product"
    if re.search(women_pattern, text):
        return "Women's product"
    else:
        return "Unisex product"
        
df_2["Gender"] = df_2["Product Name"].str.lower().transform(gender)


#categorizing as type of products
def product_type(text):
    shoes = r"\b" + re.escape("shoes") + r"\b"
    shoe = r"\b" + re.escape("shoe") + r"\b"
    footwear_signal_1 = r"\b" + re.escape("sole") + r"\b"
    footwear_signal_2 = r"\b" + re.escape("foot") + r"\b"
    clothing = r"\b" + re.escape("clothing") + r"\b"
    accessories = r"\b" + re.escape("accessories") + r"\b"
    if re.search(shoes, text):
        return "footwear"
    if re.search(shoe, text):
        return "footwear"
    if re.search(footwear_signal_1, text):
        return "footwear"
    if re.search(footwear_signal_2, text):
        return "footwear"
    if re.search(clothing, text):
        return "clothing"
    if re.search(accessories, text):
        return "accessories"
    else:
        return "footwear" ### not "other" because this dataset appears to be all footwear, after manual inspection 

##alter description to include product name for easier seaching 
df_2["Description"] = df_2["Product Name"] + ": " + df_2["Description"]
df_2["Product Type"] = df_2["Description"].str.lower().transform(product_type)

#defining popularity in terms of review counts 
## lower scale than other dataframe due to the overall lower counts of shoe reviews in general
def popularity(numerical_input):
    if numerical_input <= 25:
        return "low popularity"
    if (numerical_input > 25) & (numerical_input <= 50):
        return "medium popularity"
    if (numerical_input > 50) & (numerical_input <= 75):
        return "high popularity"
    if numerical_input > 75:
        return "very high popularity"
df_2["Popularity"] = df_2["Reviews"].transform(popularity)


# Save cleaned version
df_2.to_csv('data/02-processed/Adidas_vs_Nike_cleaned.csv', index=False)

df_2

#summary statistics and information about the dataframe
df_2.info()


# Detect outliers in listing price
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_2['Listing Price'])
plt.title('Listing Price Distribution and Outliers')
plt.show()

# Detect outliers in sales price
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_2['Sale Price'])
plt.title('Sales Price Distribution and Outliers')
plt.show()

# looking at distribution in Listing price 
plt.figure(figsize=(20, 10))
sns.histplot(data=df_2, x='Listing Price', bins =30)
plt.title('Listing Price Distribution')
plt.show()

# looking at distribution in sales price 
plt.figure(figsize=(20, 10))
sns.histplot(data=df_2, x='Sale Price', bins =30)
plt.title('Sale Price Distribution')
plt.show()

# Looking at differences in listing price based on target gender
plt.figure(figsize=(10, 6))
sns.boxplot(data = df_2 , x='Listing Price' , hue ="Gender" )
plt.title('Listing Price Distribution by Gender Target')
plt.show()

# Looking at differences in sales price based on target gender
plt.figure(figsize=(10, 6))
sns.boxplot(data = df_2 , x='Sale Price' , hue ="Gender" )
plt.title('Sale Price Distribution by Gender Target')
plt.show()

# looking at differences in listing price based on target gender and product type 
plt.figure(figsize=(10, 6))
sns.barplot(data=df_2, x='Product Type', y='Listing Price', hue='Gender')
plt.title('Mean Listing Price by Product Type and Gender')
plt.show()

# looking at differences in listing price based on target gender and product type 
plt.figure(figsize=(10, 6))
sns.barplot(data=df_2, x='Product Type', y='Sale Price', hue='Gender')
plt.title('Mean Sale Price by Product Type and Gender')
plt.show()

# looking at correlation in listing price based on review count and product type 
sns.scatterplot(data=df_2, x='Listing Price', y='Reviews')
plt.title('Rating vs Listing Price Correlation')
plt.show()

# looking at correlation in sales price based on review count and product type 
sns.scatterplot(data=df_2, x='Sale Price', y='Reviews')
plt.title('Rating vs Sale Price Correlation')
plt.show()

# looking at distribution in listing price by popularity ((based on review counts)
plt.figure(figsize=(20, 10))
sns.boxplot(data=df_2, x='Listing Price', hue='Popularity')
plt.title('Listing Price Distribution by Popularity (based on review counts)')
plt.show()

# looking at distribution in sale price by popularity (based on review counts)
plt.figure(figsize=(20, 10))
sns.boxplot(data=df_2, x='Sale Price', hue='Popularity')
plt.title('Sale Price Distribution by Popularity (based on review counts)')
plt.show()


#summary statistics and information about the dataframe
df_2.info()

df_2.describe()
# Out:
# Shape: (3268, 10)
#                                         Product Name Product ID  \
# 0  Women's adidas Originals NMD_Racer Primeknit S...     AH2430
# 1               Women's adidas Originals Sleek Shoes     G27341
# 2                  Women's adidas Swim Puka Slippers     CM0081
# 3   Women's adidas Sport Inspired Questar Ride Shoes     B44832
# 4           Women's adidas Originals Taekwondo Shoes     D98205
#
#    Listing Price  Sale Price  Discount                    Brand  \
# 0          14999        7499        50  Adidas Adidas ORIGINALS
# 1           7599        3799        50         Adidas ORIGINALS
# 2            999         599        40        Adidas CORE / NEO
# 3           6999        3499        50        Adidas CORE / NEO
# 4           7999        3999        50         Adidas ORIGINALS
#
#                                          Description  Rating  Reviews  \
# 0  Channeling the streamlined look of an '80s rac...     4.8       41
# 1  A modern take on adidas sport heritage, tailor...     3.3       24
# 2  These adidas Puka slippers for women's come wi...     2.6       37
# 3  Inspired by modern tech runners, these women's...     4.1       35
# 4  This design is inspired by vintage Taekwondo s...     3.5       72
#
#           Last Visited
# 0  2020-04-13 15:06:14
# 1  2020-04-13 15:06:15
# 2  2020-04-13 15:06:15
# 3  2020-04-13 15:06:15
# 4  2020-04-13 15:06:15
# Missing values:
#  Product Name     0
# Product ID       0
# Listing Price    0
# Sale Price       0
# Discount         0
# Brand            0
# Description      3
# Rating           0
# Reviews          0
# Last Visited     0
# dtype: int64
# Missing values:
#  Product Name     0
# Product ID       0
# Listing Price    0
# Sale Price       0
# Discount         0
# Brand            0
# Description      0
# Rating           0
# Reviews          0
# Last Visited     0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 2625 entries, 0 to 2624
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product Name   2625 non-null   object
#  1   Product ID     2625 non-null   object
#  2   Listing Price  2625 non-null   float64
#  3   Sale Price     2625 non-null   float64
#  4   Discount       2625 non-null   int64
#  5   Brand          2625 non-null   object
#  6   Description    2625 non-null   object
#  7   Rating         2625 non-null   float64
#  8   Reviews        2625 non-null   int64
#  9   Last Visited   2625 non-null   object
#  10  Gender         2625 non-null   object
#  11  Product Type   2625 non-null   object
#  12  Popularity     2625 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 287.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2625 entries, 0 to 2624
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product Name   2625 non-null   object
#  1   Product ID     2625 non-null   object
#  2   Listing Price  2625 non-null   float64
#  3   Sale Price     2625 non-null   float64
#  4   Discount       2625 non-null   int64
#  5   Brand          2625 non-null   object
#  6   Description    2625 non-null   object
#  7   Rating         2625 non-null   float64
#  8   Reviews        2625 non-null   int64
#  9   Last Visited   2625 non-null   object
#  10  Gender         2625 non-null   object
#  11  Product Type   2625 non-null   object
#  12  Popularity     2625 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 287.1+ KB
#        Listing Price   Sale Price     Discount       Rating      Reviews
# count    2625.000000  2625.000000  2625.000000  2625.000000  2625.000000
# mean       76.009810    51.350042    33.459048     3.366362    48.725714
# std        40.710145    35.899904    20.431622     1.159873    28.926042
# min         8.990000     4.490000     0.000000     0.000000     0.000000
# 25%        49.990000    27.990000     0.000000     2.700000    24.000000
# 50%        65.990000    39.990000    40.000000     3.500000    49.000000
# 75%        89.990000    64.990000    50.000000     4.300000    74.000000
# max       299.990000   299.990000    60.000000     5.000000    99.000000

# %%
#to prepare for combining the dataframes, we must rename the columns of the dataframes to match, 
#and make sure the columns we want to combine are of the same datatype

print(df.columns)
print(df_2.columns)

df.info()
df_2.info()

#renaming columns to be able to concatinate them 
rename= ["Index", "URL", "Product Name", "SKU", "Sale Price", "Listing Price", "Currency", "Availibility", "Color", "Category" ,"Source", "Source Website", "Breadcrumbs", "Description", "Brand", "Images", "Country", "Language","Rating", "Reviews", "Crawled At", "Gender", "Product Type", "Popularity"]
df.columns = rename
#making sure the data type is the same
df["Sale Price"] = df["Sale Price"] .astype(float)
merged = pd.concat([df,df_2], ignore_index = True)
merged
# Out:
# Index(['index', 'url', 'name', 'sku', 'selling_price', 'original_price',
#        'currency', 'availability', 'color', 'category', 'source',
#        'source_website', 'breadcrumbs', 'description', 'brand', 'images',
#        'country', 'language', 'average_rating', 'reviews_count', 'crawled_at',
#        'gender', 'product_type', 'popularity'],
#       dtype='object')
# Index(['Product Name', 'Product ID', 'Listing Price', 'Sale Price', 'Discount',
#        'Brand', 'Description', 'Rating', 'Reviews', 'Last Visited', 'Gender',
#        'Product Type', 'Popularity'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Index: 829 entries, 15 to 844
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           829 non-null    int64
#  1   url             829 non-null    object
#  2   name            829 non-null    object
#  3   sku             829 non-null    object
#  4   selling_price   829 non-null    int64
#  5   original_price  829 non-null    float64
#  6   currency        829 non-null    object
#  7   availability    829 non-null    object
#  8   color           829 non-null    object
#  9   category        829 non-null    object
#  10  source          829 non-null    object
#  11  source_website  829 non-null    object
#  12  breadcrumbs     829 non-null    object
#  13  description     829 non-null    object
#  14  brand           829 non-null    object
#  15  images          829 non-null    object
#  16  country         829 non-null    object
#  17  language        829 non-null    object
#  18  average_rating  829 non-null    float64
#  19  reviews_count   829 non-null    int64
#  20  crawled_at      829 non-null    object
#  21  gender          829 non-null    object
#  22  product_type    829 non-null    object
#  23  popularity      829 non-null    object
# dtypes: float64(2), int64(3), object(19)
# memory usage: 161.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2625 entries, 0 to 2624
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product Name   2625 non-null   object
#  1   Product ID     2625 non-null   object
#  2   Listing Price  2625 non-null   float64
#  3   Sale Price     2625 non-null   float64
#  4   Discount       2625 non-null   int64
#  5   Brand          2625 non-null   object
#  6   Description    2625 non-null   object
#  7   Rating         2625 non-null   float64
#  8   Reviews        2625 non-null   int64
#  9   Last Visited   2625 non-null   object
#  10  Gender         2625 non-null   object
#  11  Product Type   2625 non-null   object
#  12  Popularity     2625 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 287.1+ KB
#       Index                                                URL  \
# 0      15.0  https://www.adidas.com/us/essentials-loose-log...
# 1      16.0  https://www.adidas.com/us/essentials-loose-log...
# 2      18.0  https://www.adidas.com/us/essentials-loose-log...
# 3      19.0  https://www.adidas.com/us/formotion-sculpt-tig...
# 4      20.0  https://www.adidas.com/us/marvel-x-ghosted.3-f...
# ...     ...                                                ...
# 3449    NaN                                                NaN
# 3450    NaN                                                NaN
# 3451    NaN                                                NaN
# 3452    NaN                                                NaN
# 3453    NaN                                                NaN
#
#                                          Product Name     SKU  Sale Price  \
# 0                      Essentials Loose Logo Tank Top  H07758       20.00
# 1                      Essentials Loose Logo Tank Top  H07757       20.00
# 2                      Essentials Loose Logo Tank Top  H07756       20.00
# 3                             Formotion Sculpt Tights  GN9137       48.00
# 4               Marvel X Ghosted.3 Firm Ground Cleats  FZ1757       64.00
# ...                                               ...     ...         ...
# 3449            Men's adidas Adipower Vector 20 Shoes     NaN      109.99
# 3450                Men's adidas Cricket Howzat Shoes     NaN       69.99
# 3451                     Men's Cricket Cri Hase Shoes     NaN       39.99
# 3452  Unisex adidas Outdoor Terrex Daroga Water Shoes     NaN       79.99
# 3453      Men's adidas Basketball Harden Vol. 4 Shoes     NaN      149.99
#
#       Listing Price Currency Availibility   Color  Category  ... Language  \
# 0             25.00      USD      InStock  Purple  Clothing  ...       en
# 1             25.00      USD      InStock    Pink  Clothing  ...       en
# 2             25.00      USD      InStock   Green  Clothing  ...       en
# 3             80.00      USD      InStock    Blue  Clothing  ...       en
# 4             80.00      USD      InStock    Blue     Shoes  ...       en
# ...             ...      ...          ...     ...       ...  ...      ...
# 3449         109.99      NaN          NaN     NaN       NaN  ...      NaN
# 3450          69.99      NaN          NaN     NaN       NaN  ...      NaN
# 3451          39.99      NaN          NaN     NaN       NaN  ...      NaN
# 3452          79.99      NaN          NaN     NaN       NaN  ...      NaN
# 3453         149.99      NaN          NaN     NaN       NaN  ...      NaN
#
#      Rating Reviews Crawled At           Gender Product Type  \
# 0       4.8     116    50:19.6  Women's product     clothing
# 1       4.8     116    50:19.8  Women's product     clothing
# 2       4.8     116    50:20.0  Women's product     clothing
# 3       4.2     144    50:20.1  Women's product     clothing
# 4       4.4     160    50:20.1   Unisex product     footwear
# ...     ...     ...        ...              ...          ...
# 3449    4.9      47        NaN    Men's product     footwear
# 3450    4.4      30        NaN    Men's product     footwear
# 3451    2.0      87        NaN    Men's product     footwear
# 3452    4.6       6        NaN   Unisex product     footwear
# 3453    4.4      89        NaN    Men's product     footwear
#
#                 Popularity Product ID  Discount         Last Visited
# 0          high popularity        NaN       NaN                  NaN
# 1          high popularity        NaN       NaN                  NaN
# 2          high popularity        NaN       NaN                  NaN
# 3          high popularity        NaN       NaN                  NaN
# 4     very high popularity        NaN       NaN                  NaN
# ...                    ...        ...       ...                  ...
# 3449     medium popularity     EF3503       0.0  2020-04-13 15:07:59
# 3450     medium popularity     EF3505       0.0  2020-04-13 15:07:59
# 3451  very high popularity     CM6008       0.0  2020-04-13 15:07:59
# 3452        low popularity     BC0980       0.0  2020-04-13 15:07:59
# 3453  very high popularity     EF9924       0.0  2020-04-13 15:07:59
#
# [3454 rows x 27 columns]

# %%
##checking columns
print("Merged dataframe columns pre-wrangling: ", merged.columns)

#dropping unnecessary columns from merged DF
merged = merged.drop(columns = ['Index', 'URL', 'Availibility', 'Category', 'Source',  'Source Website', 'Breadcrumbs', 'Brand', 'Images', 'Language', "Discount", "SKU", "Last Visited", "Crawled At", "Product ID"])

#the entire dataset is in USD
merged["Currency"] = merged["Currency"].fillna("USD") 

##default umbrella color designation 
merged["Color"] = merged["Color"].fillna("Multicolor") 
## making sure all "multiple color" terms are labelled the same
merged.loc[merged[merged["Color"] == "Multi"].index, "Color"] = "Multicolor"

##Default, just adidas products that were sold in unknown countries, 
#can assume the United States was one of them but unverifiable - thus, "Various" umbrella designation
merged["Country"] = merged["Country"].fillna("Various") 

##making sure that target gender is designated as "unisex" if not for men or women 
merged["Gender"]

##saving the merged data to the datafile
merged.to_csv('data/02-processed/merged.csv', index=False)
##showing columns we have as end result
print("Merged dataframe columns post-wrangling: ", merged.columns)
merged
# Out:
# Merged dataframe columns pre-wrangling:  Index(['Index', 'URL', 'Product Name', 'SKU', 'Sale Price', 'Listing Price',
#        'Currency', 'Availibility', 'Color', 'Category', 'Source',
#        'Source Website', 'Breadcrumbs', 'Description', 'Brand', 'Images',
#        'Country', 'Language', 'Rating', 'Reviews', 'Crawled At', 'Gender',
#        'Product Type', 'Popularity', 'Product ID', 'Discount', 'Last Visited'],
#       dtype='object')
# Merged dataframe columns post-wrangling:  Index(['Product Name', 'Sale Price', 'Listing Price', 'Currency', 'Color',
#        'Description', 'Country', 'Rating', 'Reviews', 'Gender', 'Product Type',
#        'Popularity'],
#       dtype='object')
#                                          Product Name  Sale Price  \
# 0                      Essentials Loose Logo Tank Top       20.00
# 1                      Essentials Loose Logo Tank Top       20.00
# 2                      Essentials Loose Logo Tank Top       20.00
# 3                             Formotion Sculpt Tights       48.00
# 4               Marvel X Ghosted.3 Firm Ground Cleats       64.00
# ...                                               ...         ...
# 3449            Men's adidas Adipower Vector 20 Shoes      109.99
# 3450                Men's adidas Cricket Howzat Shoes       69.99
# 3451                     Men's Cricket Cri Hase Shoes       39.99
# 3452  Unisex adidas Outdoor Terrex Daroga Water Shoes       79.99
# 3453      Men's adidas Basketball Harden Vol. 4 Shoes      149.99
#
#       Listing Price Currency       Color  \
# 0             25.00      USD      Purple
# 1             25.00      USD        Pink
# 2             25.00      USD       Green
# 3             80.00      USD        Blue
# 4             80.00      USD        Blue
# ...             ...      ...         ...
# 3449         109.99      USD  Multicolor
# 3450          69.99      USD  Multicolor
# 3451          39.99      USD  Multicolor
# 3452          79.99      USD  Multicolor
# 3453         149.99      USD  Multicolor
#
#                                             Description  Country  Rating  \
# 0     Essentials Loose Logo Tank Top: What's on the ...      USA     4.8
# 1     Essentials Loose Logo Tank Top: What's on the ...      USA     4.8
# 2     Essentials Loose Logo Tank Top: What's on the ...      USA     4.8
# 3     Formotion Sculpt Tights: Sometimes confidence ...      USA     4.2
# 4     Marvel X Ghosted.3 Firm Ground Cleats: X has m...      USA     4.4
# ...                                                 ...      ...     ...
# 3449  Men's adidas Adipower Vector 20 Shoes: It's ju...  Various     4.9
# 3450  Men's adidas Cricket Howzat Shoes: Batting, fi...  Various     4.4
# 3451  Men's Cricket Cri Hase Shoes: Thiese shoes are...  Various     2.0
# 3452  Unisex adidas Outdoor Terrex Daroga Water Shoe...  Various     4.6
# 3453  Men's adidas Basketball Harden Vol. 4 Shoes: T...  Various     4.4
#
#       Reviews           Gender Product Type            Popularity
# 0         116  Women's product     clothing       high popularity
# 1         116  Women's product     clothing       high popularity
# 2         116  Women's product     clothing       high popularity
# 3         144  Women's product     clothing       high popularity
# 4         160   Unisex product     footwear  very high popularity
# ...       ...              ...          ...                   ...
# 3449       47    Men's product     footwear     medium popularity
# 3450       30    Men's product     footwear     medium popularity
# 3451       87    Men's product     footwear  very high popularity
# 3452        6   Unisex product     footwear        low popularity
# 3453       89    Men's product     footwear  very high popularity
#
# [3454 rows x 12 columns]

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# For exploratory data analysis, in addition to some of the earlier exploratory data analysis we did on the individual datasets, we plan on first exploring what the individual variables look like in this new merged dataset. So, we'll be looking at things such as spread, distribution and frequency of these individual varaibles in section 1 of our EDA before exploring potential relationships or correlations, which we will do in section 2.
#
# From our exploratory data analysis of individual variables, we observed some interesting, new things. Notably, we saw that there was much more men's athleticware than women's or unisex - approximately the same as both these categories combined. We also saw that, for the Country variable, that there were nearly triple the number of garments whose country was "Various" than whose country was "USA", which could be a significant factor in pricing later. Speaking of pricing, we also saw a trend that persisted from analysis of the individual datasets, which was that sales price was notably lower than listing price.  We also saw that most garments were multicolored by a large margin, followed by white, black, and ___. In terms of reviews of these garments, we saw an interesting divide, in that most garments had fewer, one hundred or less, reviews, but if they didn't, then they had a large number of reviews, up to the tens of thousands. Our anaysis of popularity aligned with this as well, with "Low Popularity" being the most common designation.
#
# From our exploratory data analysis between variables, we saw some general trends that were new, and some that were reflected in the individual dataset EDA we did prior.  The general trend of sales price (price the product was purchased at) being lower than the listing price (original price of the product), which was also the case in the datasets prior to merging, persisted across different variables, such as garment gender, product type, and country. Women's athleticware often had a higher listing price than men's athleticware across all apparel types (clothing, footwear, and accessories) and had a lower or equal sale price to men's apparel on average, which is something we saw from EDA on dataset #1, but a new trend we saw was that women's athleticware was purchased at a higher or equal sales price when we categorized by apparel type, across both sales price and listing price, contradicting the grouped average of all apparel types.  We also saw that when it came to country, women's apparel had lower sales price and listing price than men's apparel when the country was "USA", but higher sales price and listing price than men's apparel when the country was "various".  Unisex items were still the most costly on average across all categories, which we think could be due to some of the footwear in dataset 2, which had a higher average sales and listing price than dataset 1, or some other unseen factor, such as certain items such as trendy items that anyone can wear being particularly pricey. We didn't really see much of a pattern or trend in the "Reviews", "Rating", or "Popularity" variables when we paired them with other variables, which might indicate that they're not as significant of factors when it comes to pricing. We didn't see any clear relationships with "Color" either, but there is still interesting data there when it comes to viewing the price distribution of garment color by gender.

# %% [markdown]
# #### Section 1 of EDA - Looking at Variables Individually
#
# In this section, we explore the individual variables in the new, merged dataset created by datasets 1 and 2, as well as the data we extracted.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

## loading combined dataset 
merged

### Looking at distribution of variables within the dataset individiually 

## new listing price distribution 
plt.figure(figsize=(12, 10))
sns.boxplot(data = merged, x = "Listing Price")
plt.title('Distribution of Listing Price')
plt.show() 


## new sales price distribution 
plt.figure(figsize=(12, 10))
sns.boxplot(data = merged, x = "Sale Price")
plt.title('Distribution of Sale Price')
plt.show() 



# looking at listing price distribution 
plt.figure(figsize=(12, 10))
sns.histplot(data = merged, x = "Listing Price")
plt.title('Counts of Listing Price')
plt.show() 

# looking at sale price distribution 
plt.figure(figsize=(12, 10))
sns.histplot(data = merged, x = "Sale Price")
plt.title('Counts of Sale Price')
plt.show() 

# looking at popularity score counts/frequency  
plt.figure(figsize=(12, 10))
popularity_counts = merged["Popularity"].value_counts()
sns.barplot(popularity_counts)
plt.title('Popularity Score Counts')
plt.show() 

# looking at color counts/frequency  
plt.figure(figsize=(12, 10))
color_counts = merged["Color"].value_counts()
sns.barplot(color_counts)
plt.title('Garment Color Counts (All)')
plt.show() 

# looking at color counts/frequency WITHOUT "multicolor"
plt.figure(figsize=(12, 10))
color_counts_2 = merged["Color"].value_counts()[1:]
sns.barplot(color_counts_2)
plt.title('Garment Color Counts (Excl. Multicolor)')
plt.show() 

# looking at gender counts/frequency
plt.figure(figsize=(12, 10))
gender_counts = merged["Gender"].value_counts()
sns.barplot(gender_counts)
plt.title('Garment Gender Counts')
plt.show() 

# looking at country counts/frequency
plt.figure(figsize=(12, 10))
country_counts = merged["Country"].value_counts()
sns.barplot(country_counts)
plt.title('Garment Country Counts')
plt.show() 

# looking at rating counts
plt.figure(figsize=(12, 10))
ratings_counts = merged["Rating"].value_counts()
sns.barplot(ratings_counts)
plt.title('Ratings Counts)')
plt.show() 

# looking at rating distribution
plt.figure(figsize=(12, 10))
ratings_counts = merged["Rating"].value_counts()
sns.histplot(data = merged, x = "Rating",  stat = "count")
plt.title('Distribution of Rating Counts')
plt.show() 


# looking at review distribution by gender 
plt.figure(figsize=(25, 10))
df = pd.DataFrame(merged["Reviews"].value_counts()).reset_index()
review_counts = merged["Reviews"].value_counts()
sns.barplot(review_counts)
plt.xticks(rotation=90, size = 5)
plt.title('Review Counts')
plt.show() 


# looking at review distribution 
plt.figure(figsize=(12, 10))
sns.histplot(data = merged, x = "Reviews", stat = "density", binwidth = 50)
plt.title('Distribution of Review Counts (All)')
plt.show()

# %% [markdown]
# #### Section 2 of EDA: Exploring Potential Relationships Between Variables
#
# In this section, we explore relationships between variables in order to try to identify any interesting trends or patterns that might help us determine what factors impact athelticware pricing the most.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

## loading combined dataset 
merged


##melting data to prepare it for a side-by-side comparison of sales and listing prices by categorical columns (gender, color, product type, etc)
to_melt = merged[["Gender", "Product Type", "Listing Price", "Sale Price", "Color", "Popularity", "Rating", "Reviews", "Country"]]
merged_melted = to_melt.melt(id_vars=["Gender", "Product Type",  "Color", "Popularity", "Rating", "Reviews", "Country"], var_name='Price Type', value_name='Prices')
merged_melted


## Exploring correlations and possible relationships 

# looking at listing price distribution by gender 
plt.figure(figsize=(12, 10))
listing_counts = merged["Listing Price"].value_counts()
sns.histplot(data = merged, x = "Listing Price", hue = "Gender", stat = "count")
plt.title('Distribution of Listing Price by Garment Gender')
plt.show() 

# looking at sale price distribution by gender 
plt.figure(figsize=(12, 10))
sale_counts = merged["Sale Price"].value_counts()
sns.histplot(data = merged, x = "Sale Price", hue = "Gender")
plt.title('Distribution of Sale Price by Garment Gender')
plt.show() 


# looking at relationship between sale price and listing price by gender 
plt.figure(figsize=(10, 6))
sns.scatterplot(data=merged, x='Sale Price', y='Listing Price',  hue = "Gender")
plt.title('Sale vs Listing Price by Gender')
plt.show() 
# looking at relationship between sale price and gender 
plt.figure(figsize=(18, 10))
sns.boxplot(data=merged, x='Sale Price' , hue = "Gender")
plt.title('Sale Price by Gender')
plt.show()
# looking at relationship between listing price and gender 
plt.figure(figsize=(18, 10))
sns.boxplot(data=merged, x='Listing Price' , hue = "Gender")
plt.title('Listing Price by Gender')
plt.show()


# lookign at relationship between sales vs listing price by garment color
sns.catplot(data=merged_melted,x='Color',y='Prices', hue='Price Type',  kind='box', height=7, aspect=2 , palette = ["green", "yellow"])
plt.title('Sales vs Listing Price by Color')
plt.show() 
# looking at relationship between garment color and sale price by gender
plt.figure(figsize=(20, 10))
sns.boxplot(data=merged, x =  "Color", y = 'Sale Price', hue = 'Gender')
plt.title('Sale Price vs Garment Color by Gender')
plt.show() 
# looking at relationship between garment color and listing price by gender
plt.figure(figsize=(20, 10))
sns.boxplot(data=merged, x =  "Color", y = 'Listing Price', hue = 'Gender')
plt.title('Listing Price vs Garment Color by Gender')
plt.show() 


# lookign at relationship between sales vs listing price by product type
sns.catplot(data=merged_melted,x='Product Type',y='Prices', hue='Price Type',  kind='box', height=7, aspect=2, palette = ["green", "yellow"])
plt.title('Sales vs Listing Price by Product Type')
plt.show() 
# looking at relationship between product type and sale price by gender
plt.figure(figsize=(12, 10))
sns.boxplot(data=merged, x =  "Product Type", y = 'Sale Price', hue = "Gender")
plt.title('Product Type and Sale Price by Gender')
plt.show() 
# looking at relationship between product type and listing price by gender 
plt.figure(figsize=(12, 10))
sns.boxplot(data=merged, x =  "Product Type", y = 'Listing Price', hue = "Gender")
plt.title('Product Type and Listing Price by Gender')
plt.show() 


#looking at relationship between popularity and sales vs listing prices 
sns.catplot(data=merged_melted,x='Popularity',y='Prices', hue='Price Type', kind='box', height=7, aspect=2, palette = ["green", "yellow"] )
plt.title('Sales vs Listing Price by Popularity')
plt.show() 
# looking at listing price distribution by popularity
plt.figure(figsize=(12, 10))
listing_counts = merged["Listing Price"].value_counts()
sns.histplot(data = merged, x = "Listing Price", hue = "Popularity")
plt.title('Distribution of Listing Price by Popularity')
plt.show() 
# looking at sale price distribution by popularity 
plt.figure(figsize=(12, 10))
sale_counts = merged["Sale Price"].value_counts()
sns.histplot(data = merged, x = "Sale Price", hue = "Popularity")
plt.title('Distribution of Sale Price by Popularity')
plt.show() 

## looking at relationship between Country and Price Type
sns.catplot(data=merged_melted,x='Country',y='Prices', hue='Price Type', kind='box', height=7, aspect=2, palette = ["green", "yellow"] )
plt.title('Sales vs Listing Price by Country')
plt.show() 
## looking at relationship between Country and Listing Price by Garment Gender
plt.figure(figsize=(20, 10))
sns.boxplot(data=merged, x='Country', y='Listing Price', hue = "Gender")
plt.title("Country vs Listing Price by Garment Gender")
plt.show()  
## looking at relationship between Country and Sale Price by Garment Gender
plt.figure(figsize=(20, 10))
sns.boxplot(data=merged, x='Country', y='Sale Price', hue = "Gender")
plt.title("Country vs Sale Price by Garment Gender")
plt.show()  


## looking at relationship between review count and rating 
plt.figure(figsize=(20, 10))
sns.barplot(data=merged, x='Rating', y='Reviews')
plt.title("Distribution of Review Counts over Ratings")
plt.show()  

## looking at relationship between review count and rating by gender
plt.figure(figsize=(20, 10))
sns.barplot(data=merged, x='Rating', y='Reviews', hue = "Gender", hue_order = ["Women's product", "Unisex product", "Men's product"])
plt.title("Distribution of Review Counts over Ratings by Garment Gender")
plt.show()

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data used to which they consent?
# > There are no human subjects involved in our data collection.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
# > This study reflects pricing and marketing choices specific to only one brand/company because the data being analyzed comes only from Adidas. This limits an overall general analysis of the larger athleticwear industry and introduces potential bias. Additionally, our dataset(s) focus on U.S. pricing and consumer trends, overlooking regional variations in pricing and affordability, which may skew perceptions of product value across global markets. To limit any bias, we will clearly mention that the results from this project describe pricing strategies specific to Adidas pricing structure only and not the entire athleticwear industry to avoid overstating our conclusions.
#
#  - [ ] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
# > There is no personal information that is being collected in our data collection, and no privacy risks are present. All of the data is related to the products, not the individuals themselves.
#
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
# > We will check for unbalanced groups, especially with gender-specific items and the pricing associated with those products, to ensure that our model doesn't unintentionally reinforce bias or social stereotypes through Adidas’s marketing/pricing decisions.
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
# > No sensitive information is being stored. The datasets are from Kaggle and downloaded to a secure environment.
#
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
# > Not applicable to our project since the datasets were publicly shared by Kaggle and no personal information is stored or shared in the datasets.
#
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
# > The data will be archived and/or deleted after our team finalizes analyzing and producing results - when the project concludes.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
# > Our dataset only includes Adidas products, which lacks perspectives and inputs from other both larger and smaller athleticwear companies.We will make sure that we clearly state that our analysis only focuses on Adidas, and doesn't represent the dynamics of the broader athleticwear industry.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
# > We will make sure that we check for any imbalanced classes/representation in certain product features (material, color, category, origin, gender-target) within our data before moving into the modeling process. If we find any uneven representation, we will make sure to be transparent about it in our results.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
# > We will clearly and honestly state our data cleaning, analysis and modeling process steps and make sure that our visualizations and reports accurately reflect our findings. Our team will also be explicit in stating that the correlations we find are descriptive of Adidas’s dataset(s) and not causal.
#
#  - [ ] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
# > No PII exists in our data, so there are no privacy risks or concerns regarding this.
#
#  - [ ] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
# > All steps of analysis and modeling will be well documented in a Jupyter Notebook and in the GitHub repository to allow any replication in the future.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
# > Since the dataset does include a gender-target variable, we will analyze to see if gendered products have consistent pricing patterns. We will check any gender-specific products to avoid reinforcing any stereotypes.This will ensure that our results do not unintentionally reproduce or justify disparities within pricing.
#
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
# > We will check for any variations in pricing when it comes to gender-specific products to make sure that our results are neutral and not biased in any kind of way. We will test whether pricing across different categories are statistically significant and if they reflect Adidas’s marketing decisions.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
# > We will use modeling techniques such as multiple linear regression to analyze the features in our data and loss functions such as MAE and/or MSE (Mean Absolute Error and/or Mean Squared Error) to optimize our defined metrics and for transparency.
#
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
# > Coefficients and features that are involved in regression and other visualizations will be used to show how each variable, such as material, color, category, origin, gender-target, influences the pricing of a product. This will ensure that our results are understandable for a general audience.
#
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
# > We will communicate our findings very carefully to ensure that readers understand that our analysis applies only to Adidas’s dataset. This is because we are aware that misinterpreting our results as an attempt to generalize pricing across all brands could unintentionally reinforce misleading marketing assumptions. Our findings will be communicated to be specific to Adidas's marketing and pricing strategy, not pricing for products in the broader athleticwear industry. We will include clear disclaimers in our project to prevent any misunderstanding and communicate these limitations.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
# > Not applicable because our team is not planning to deploy this model.
#
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
# > Not applicable because individuals are not particularly affected by any outcomes of this model.
#
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
# > Not applicable because our model is not under production.
#
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
# > We will make sure to clarify that our model should not be used to justify variations in pricing within different product categories.
# While our model is not being deployed to the public, our findings in our model/project could be misused if taken out of context. For instance, someone could use our analysis from this project to justify the pricing differences for products by gender. To prevent any misuse and misinterpretation like this, we will explicitly state that our research does not justify, recommend, or endorse any discriminatory pricing strategies, especially for explicit commercial use. We will make a clear disclaimer which states that it is unethical to use our results/analysis for commercial use and pricing for products without proper equity testing, since it can perpetuate gender and/or economic inequalities.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# **Team Members:** Shourya Kulkarni, Pauline Shah, Muska Mesdaq, Jasmine Le
#
# **Team Expectation 1:** Communication and Collaboration
# Our team will communicate primarily through iMessage, providing frequent updates throughout the week. We’ll also hold FaceTime calls if necessary to check in on progress, assign tasks, and discuss any challenges. Everyone agrees to respond to messages within 24 hours on weekdays. We’ll keep communication clear and respectful, using a “blunt but polite” tone.
#
# **Team Expectation 2:** Task Distribution and Accountability
# Each team member will contribute equally to the project while focusing on their strengths. We’ll track progress using a shared Google Doc or GitHub Projects board. If someone is struggling to complete a task, they will notify the group at least one day in advance so adjustments can be made. Repeated lack of communication or contribution will be documented and reported if necessary.
#
# **Team Expectation 3:** Respectful Conflict Resolution
# We’ll address any disagreements calmly and constructively, discussing them through iMessage or FaceTime. If an issue cannot be resolved within the team, the professor will be contacted per course policy.
#
# **Team Expectation 4:** Professionalism and Commitment
# Each member commits to staying engaged, meeting deadlines, writing clear and well-commented code, and helping edit project documents. Everyone will maintain a respectful and collaborative attitude throughout the quarter.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: Replace this with your timeline.  **PLEASE UPDATE your Timeline!** No battle plan survives contact with the enemy, so make sure we understand how your plans have changed.  Also if you have lost points on the previous checkpoint fix them
# | Week | Dates | Goals & Tasks | Deliverables / Check-ins |
# |------|-------|---------------|--------------------------|
# | **Week 5** | **Oct 28 – Nov 3** | • Finalize data science question and hypotheses.<br>• Search for and clean datasets.<br>• Assign roles (wrangling, visualization, writing, communication). | Clear research question, dataset confirmed, and GitHub repo organized. |
# | **Week 6** | **Nov 4 – Nov 10** | • Begin **data wrangling and exploration**.<br>• Handle missing data, variable formatting, and merge datasets.<br>• Early exploratory plots to understand distributions. | Draft of wrangling and EDA sections pushed to GitHub. |
# | **Week 7** | **Nov 11 – Nov 17** | • Conduct deeper **EDA and preliminary analysis** (correlations, trends, regressions, etc.).<br>• Meet to interpret findings and refine hypotheses.<br>• Begin writing “Methods” section. | EDA visuals and first analysis summary completed. |
# | **Week 8** | **Nov 18 – Nov 24** | • Finalize main **analysis and modeling** (if applicable).<br>• Start writing “Results” and “Discussion.”<br>• Peer review teammates’ code and markdown explanations. | Completed analysis code and preliminary write-up in notebook. |
# | **Week 9** | **Nov 25 – Dec 1** | • Create clean **visualizations** and polish narrative flow.<br>• Integrate feedback from TA / peers.<br>• Begin editing and proofreading entire notebook. | Draft of final report ready for revision. |
# | **Week 10** | **Dec 2 – Dec 9** | • Final revisions, formatting, and submission prep.<br>• Double-check references, figure captions, and README file.<br>• Submit final project by deadline. | Final project submitted on GitHub and Canvas. |
# | **Finals Week** | **Dec 10** | • Ensure project is properly turned in and accessible.<br>• Complete group reflection / survey if required. | Confirmation of successful submission and survey completion. |
